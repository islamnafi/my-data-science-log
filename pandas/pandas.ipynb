# %% [markdown]
# # ***Importing Pandas***

# %%
import pandas as pd

# %% [markdown]
# # ***Creating a dataframe from a python list***

# %%
temp_df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['c1','c2','c3'], index=['r1','r2','r3'])

# %%
temp_df.head()
# Out:
#     c1  c2  c3
# r1   1   2   3
# r2   4   5   6
# r3   7   8   9

# %% [markdown]
# # ***Importing a csv file***

# %%
df = pd.read_csv("https://raw.githubusercontent.com/islamnafi/my-data-science-log/refs/heads/main/pandas/obesity_prediction.csv")

# %% [markdown]
# #  ***Exploring the details of the dataframe***

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
df.tail(10)
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2101  Female  25.722004  1.628470  107.218949            yes  yes   3.0  3.0
# 2102  Female  25.765628  1.627839  108.107360            yes  yes   3.0  3.0
# 2103  Female  21.016849  1.724268  133.033523            yes  yes   3.0  3.0
# 2104  Female  21.682367  1.732383  133.043941            yes  yes   3.0  3.0
# 2105  Female  21.285965  1.726920  131.335786            yes  yes   3.0  3.0
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# ...

# %%
df.sample(10)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 669     Male  21.084625  1.787264   58.585146            yes  yes  2.530233
# 610   Female  21.798856  1.672007   49.980968            yes  yes  2.979383
# 1787    Male  24.511445  1.852664  121.310257            yes  yes  2.906269
# 138     Male  31.000000  1.760000   75.000000            yes   no  3.000000
# 1735    Male  26.734476  1.816197  119.622764            yes  yes  2.247037
# 1382  Female  26.220065  1.560258   78.435904            yes  yes  2.108163
# 1564    Male  30.304203  1.703202  103.034400            yes  yes  2.754645
# 474     Male  19.000000  1.780000   64.000000             no  yes  2.000000
# 2040  Female  25.982261  1.629225  104.838425            yes  yes  3.000000
# 2038  Female  26.000000  1.608283  105.359688            yes  yes  3.000000
#
#            NCP        CAEC SMOKE      CH2O  SCC       FAF       TUE  \
# ...

# %%
df.sample(frac= 0.01)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 765   Female  30.958957  1.633491   68.803694            yes  yes  2.052152
# 236   Female  21.000000  1.660000   59.000000             no  yes  1.000000
# 76    Female  24.000000  1.600000   45.000000            yes   no  2.000000
# 1225    Male  23.252906  1.775815   97.813023            yes  yes  2.000000
# 837     Male  22.851773  1.752115   79.414603            yes  yes  3.000000
# 1076    Male  24.068940  1.706912   85.743727            yes  yes  2.000000
# 512   Female  22.038327  1.711467   51.965521            yes  yes  2.880161
# 32    Female  24.000000  1.770000   76.000000             no   no  2.000000
# 307   Female  23.000000  1.590000   48.000000            yes  yes  2.000000
# 1858  Female  26.000000  1.610636  105.423532            yes  yes  3.000000
# 342     Male  23.000000  1.740000  105.000000            yes  yes  3.000000
# ...

# %%
df.sample(10, random_state=27)
# Out:
#       Gender        Age    Height      Weight family_history FAVC      FCVC  \
# 1541    Male  31.868930  1.750000  118.102897            yes  yes  2.139196
# 2068  Female  24.196367  1.697421  114.482386            yes  yes  3.000000
# 591     Male  19.556729  1.767563   56.307019            yes  yes  2.362918
# 201   Female  41.000000  1.540000   80.000000            yes  yes  2.000000
# 1801  Female  18.233541  1.792378  137.859737            yes  yes  3.000000
# 1419    Male  31.783524  1.672959   90.000000            yes  yes  2.949242
# 260     Male  21.000000  1.720000   75.000000             no  yes  2.000000
# 1420    Male  29.681308  1.680058   89.994351            yes  yes  2.104772
# 1799  Female  25.919241  1.611462  102.093223            yes  yes  3.000000
# 542   Female  19.633898  1.660840   49.039794             no   no  2.750715
#
#            NCP        CAEC SMOKE      CH2O SCC       FAF       TUE       CALC  \
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Height', 'Weight', 'family_history', 'FAVC', 'FCVC',
#        'NCP', 'CAEC', 'SMOKE', 'CH2O', 'SCC', 'FAF', 'TUE', 'CALC', 'MTRANS',
#        'Obesity'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'Obesity']

# %%
df.columns.tolist()
# Out:
# ['Gender',
#  'Age',
#  'Height',
#  'Weight',
#  'family_history',
#  'FAVC',
#  'FCVC',
#  'NCP',
#  'CAEC',
#  'SMOKE',
#  'CH2O',
#  'SCC',
#  'FAF',
#  'TUE',
#  'CALC',
#  'MTRANS',
#  'Obesity']

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.size
# Out:
# 35887

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          2111 non-null   object
#  1   Age             2111 non-null   float64
#  2   Height          2111 non-null   float64
#  3   Weight          2111 non-null   float64
#  4   family_history  2111 non-null   object
#  5   FAVC            2111 non-null   object
#  6   FCVC            2111 non-null   float64
#  7   NCP             2111 non-null   float64
#  8   CAEC            2111 non-null   object
#  9   SMOKE           2111 non-null   object
#  10  CH2O            2111 non-null   float64
#  11  SCC             2111 non-null   object
#  12  FAF             2111 non-null   float64
#  13  TUE             2111 non-null   float64
#  14  CALC            2111 non-null   object
#  15  MTRANS          2111 non-null   object
#  16  Obesity         2111 non-null   object
# ...

# %% [markdown]
# # ***Accessing the data***

# %%
df.loc[0, 'Age']
# Out:
# np.float64(21.0)

# %%
df.loc[0:4, 'Age'] #4 is inclusive
# Out:
# 0    21.0
# 1    21.0
# 2    23.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %%
df.loc[[0,7,10], ['Age', 'Height', 'Weight']]
# Out:
#      Age  Height  Weight
# 0   21.0    1.62    64.0
# 7   22.0    1.64    53.0
# 10  26.0    1.85   105.0

# %%
df.loc[ : , 'Age':'FAF']
# Out:
#             Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 0     21.000000  1.620000   64.000000            yes   no   2.0  3.0
# 1     21.000000  1.520000   56.000000            yes   no   3.0  3.0
# 2     23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3     27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4     22.000000  1.780000   89.800000             no   no   2.0  1.0
# ...         ...       ...         ...            ...  ...   ...  ...
# 2106  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
#            CAEC SMOKE      CH2O  SCC       FAF
# 0     Sometimes    no  2.000000   no  0.000000
# ...

# %%
df.iloc[0:10, 0:2] #10 and 2 are not inclusive
# Out:
#    Gender   Age
# 0  Female  21.0
# 1  Female  21.0
# 2    Male  23.0
# 3    Male  27.0
# 4    Male  22.0
# 5    Male  29.0
# 6  Female  23.0
# 7    Male  22.0
# 8    Male  24.0
# 9    Male  22.0

# %%
df.iloc[[10,20,30], [0,1,2]]
# Out:
#    Gender   Age  Height
# 10   Male  26.0    1.85
# 20   Male  22.0    1.65
# 30   Male  29.0    1.77

# %%
df.at[0, 'Age']
# Out:
# np.float64(21.0)

# %%
df.iat[0, 1]
# Out:
# np.float64(21.0)

# %%
df['Age']
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %%
df.Age #problematic if the column name has a space
# Out:
# 0       21.000000
# 1       21.000000
# 2       23.000000
# 3       27.000000
# 4       22.000000
#           ...
# 2106    20.976842
# 2107    21.982942
# 2108    22.524036
# 2109    24.361936
# 2110    23.664709
# Name: Age, Length: 2111, dtype: float64

# %% [markdown]
# # ***Filtering data***

# %%
df.head(10)
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  21.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
# 5    Male  29.0    1.62    53.0             no  yes   2.0  3.0  Sometimes
# 6  Female  23.0    1.50    55.0            yes  yes   3.0  3.0  Sometimes
# 7    Male  22.0    1.64    53.0             no   no   2.0  3.0  Sometimes
# 8    Male  24.0    1.78    64.0            yes  yes   3.0  3.0  Sometimes
# 9    Male  22.0    1.72    68.0            yes  yes   2.0  3.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# ...

# %%
df.loc[df['Weight']>70]
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# 10      Male  26.000000  1.850000  105.000000            yes  yes   3.0  3.0
# 11    Female  21.000000  1.720000   80.000000            yes  yes   2.0  3.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
df[df['Weight']>70] #works without loc() function
# Out:
#       Gender        Age    Height      Weight family_history FAVC  FCVC  NCP  \
# 2       Male  23.000000  1.800000   77.000000            yes   no   2.0  3.0
# 3       Male  27.000000  1.800000   87.000000             no   no   3.0  3.0
# 4       Male  22.000000  1.780000   89.800000             no   no   2.0  1.0
# 10      Male  26.000000  1.850000  105.000000            yes  yes   3.0  3.0
# 11    Female  21.000000  1.720000   80.000000            yes  yes   2.0  3.0
# ...      ...        ...       ...         ...            ...  ...   ...  ...
# 2106  Female  20.976842  1.710730  131.408528            yes  yes   3.0  3.0
# 2107  Female  21.982942  1.748584  133.742943            yes  yes   3.0  3.0
# 2108  Female  22.524036  1.752206  133.689352            yes  yes   3.0  3.0
# 2109  Female  24.361936  1.739450  133.346641            yes  yes   3.0  3.0
# 2110  Female  23.664709  1.738836  133.472641            yes  yes   3.0  3.0
#
# ...

# %%
df[(df['Weight']<60) & (df['Age']>20) & (df['Gender'] == 'Male')]
# Out:
#     Gender        Age    Height     Weight family_history FAVC      FCVC  \
# 5     Male  29.000000  1.620000  53.000000             no  yes  2.000000
# 7     Male  22.000000  1.640000  53.000000             no   no  2.000000
# 12    Male  22.000000  1.650000  56.000000             no   no  3.000000
# 63    Male  22.000000  1.680000  55.000000            yes  yes  2.000000
# 85    Male  23.000000  1.650000  58.500000            yes   no  2.000000
# 118   Male  23.000000  1.620000  53.000000            yes  yes  2.000000
# 122   Male  21.000000  1.750000  50.000000            yes   no  3.000000
# 131   Male  23.000000  1.620000  58.000000             no   no  2.000000
# 214   Male  21.000000  1.650000  53.000000            yes  yes  2.000000
# 263   Male  23.000000  1.740000  53.000000             no  yes  2.000000
# 390   Male  23.000000  1.710000  50.000000            yes  yes  2.000000
# 509   Male  22.285024  1.753760  55.879263            yes  yes  2.450218
# ...

# %%
len(df[(df['Weight']<60) & (df['Age']>20) & (df['Gender'] == 'Male')])
# Out:
# 17

# %%
df[df['Obesity'].str.contains('Normal')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0    Female  21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1    Female  21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 2      Male  23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes
# 5      Male  29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes
# 6    Female  23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 491    Male  25.0    1.66    68.0             no  yes   2.0  3.0   Sometimes
# 493    Male  20.0    1.80    65.0             no  yes   2.0  3.0  Frequently
# 494  Female  18.0    1.67    66.0             no  yes   3.0  3.0   Sometimes
# 495    Male  19.0    1.80    60.0            yes  yes   3.0  1.0      Always
# 497    Male  20.0    1.56    45.0             no   no   2.0  3.0   Sometimes
#
# ...

# %%
df[df['Obesity'].str.startswith('Normal')]
# Out:
#      Gender   Age  Height  Weight family_history FAVC  FCVC  NCP        CAEC  \
# 0    Female  21.0    1.62    64.0            yes   no   2.0  3.0   Sometimes
# 1    Female  21.0    1.52    56.0            yes   no   3.0  3.0   Sometimes
# 2      Male  23.0    1.80    77.0            yes   no   2.0  3.0   Sometimes
# 5      Male  29.0    1.62    53.0             no  yes   2.0  3.0   Sometimes
# 6    Female  23.0    1.50    55.0            yes  yes   3.0  3.0   Sometimes
# ..      ...   ...     ...     ...            ...  ...   ...  ...         ...
# 491    Male  25.0    1.66    68.0             no  yes   2.0  3.0   Sometimes
# 493    Male  20.0    1.80    65.0             no  yes   2.0  3.0  Frequently
# 494  Female  18.0    1.67    66.0             no  yes   3.0  3.0   Sometimes
# 495    Male  19.0    1.80    60.0            yes  yes   3.0  1.0      Always
# 497    Male  20.0    1.56    45.0             no   no   2.0  3.0   Sometimes
#
# ...

# %% [markdown]
# # ***Updating data***

# %%
df.loc[0,'Age'] = 22

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  22.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.80    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.80    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...

# %%
df.loc[[2,3], 'Height'] = 1.6

# %%
df.head()
# Out:
#    Gender   Age  Height  Weight family_history FAVC  FCVC  NCP       CAEC  \
# 0  Female  22.0    1.62    64.0            yes   no   2.0  3.0  Sometimes
# 1  Female  21.0    1.52    56.0            yes   no   3.0  3.0  Sometimes
# 2    Male  23.0    1.60    77.0            yes   no   2.0  3.0  Sometimes
# 3    Male  27.0    1.60    87.0             no   no   3.0  3.0  Sometimes
# 4    Male  22.0    1.78    89.8             no   no   2.0  1.0  Sometimes
#
#   SMOKE  CH2O  SCC  FAF  TUE        CALC                 MTRANS  \
# 0    no   2.0   no  0.0  1.0          no  Public_Transportation
# 1   yes   3.0  yes  3.0  0.0   Sometimes  Public_Transportation
# 2    no   2.0   no  2.0  1.0  Frequently  Public_Transportation
# 3    no   2.0   no  2.0  0.0  Frequently                Walking
# 4    no   2.0   no  0.0  0.0   Sometimes  Public_Transportation
#
#                Obesity
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# ...
